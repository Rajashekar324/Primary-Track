# %%
# %pip install pandas matplotlib -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("student.csv")
print("Original Data:\n", df, "\n")
print("Missing values:\n", df.isnull(), "\n")
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
df["City"] = df["City"].str.strip().str.title()
print("Cleaned Data:\n", df, "\n")
avg_marks = df["Marks"].mean()
print("Average Marks:", avg_marks)
top_student = df.loc[df["Marks"].idxmax()]
print("\nTop Scoring Student:\n", top_student)
below_70 = df[df["Marks"] < 70]
print("\nStudents scoring below 70:\n", below_70)
plt.bar(df["Name"], df["Marks"])
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Marks vs Students")
plt.show()
# Out:
# Original Data:
#        name   age  marks
# 0    Alice  20.0    NaN
# 1      Bob  22.0   90.0
# 2  Charlie  21.0   78.0
# 3    David   NaN   92.0
# 4      Eve  20.0   88.0
# 5    Frank  22.0    NaN
# 6    Grace   NaN   95.0
# 7    Heidi  23.0    NaN
# 8     Ivan  20.0   91.0
# 9     Judy  22.0   87.0
#
# Missing values:
#      name    age  marks
# 0  False  False   True
# 1  False  False  False
# 2  False  False  False
# 3  False   True  False
# 4  False  False  False
# 5  False  False   True
# 6  False   True  False
# 7  False  False   True
# 8  False  False  False
# 9  False  False  False
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\RAJASHEKAR\OneDrive\Documents\CapG_Training\Python\PT Day 8\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 6
#       4 print("Original Data:\n", df, "\n")
#       5 print("Missing values:\n", df.isnull(), "\n")
# ----> 6 df["Age"] = df["Age"].fillna(df["Age"].mean())
#       7 df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
#       8 df["City"] = df["City"].str.strip().str.title()
#
# File c:\Users\RAJASHEKAR\OneDrive\Documents\CapG_Training\Python\PT Day 8\.venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\RAJASHEKAR\OneDrive\Documents\CapG_Training\Python\PT Day 8\.venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Age'
